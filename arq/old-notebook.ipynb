# %%
import os
from pyais import decode
import pandas as pd

# %%
# Decode single or multi-part messages
def decode_message(lines, start_idx, multi_part_buffer):
    line = lines[start_idx].strip()
    parts = line.split(',')
    if len(parts) < 6 or not parts[5]:
        raise ValueError("Empty or malformed payload")
    
    if parts[1] == "2" and parts[2] == "1":  # First part
        seq_id = parts[3]
        if start_idx + 1 < len(lines) and lines[start_idx + 1].split(',')[1] == "2" and lines[start_idx + 1].split(',')[2] == "2" and lines[start_idx + 1].split(',')[3] == seq_id:
            return decode(line.split(',2024-')[0], lines[start_idx + 1].split(',2024-')[0])
        else:
            multi_part_buffer[seq_id] = line
            raise ValueError("Missing second part")
    elif parts[1] == "2" and parts[2] == "2":  # Second part
        seq_id = parts[3]
        if seq_id in multi_part_buffer:
            decoded = decode(multi_part_buffer[seq_id].split(',2024-')[0], line.split(',2024-')[0])
            del multi_part_buffer[seq_id]
            return decoded
        raise ValueError("Missing first part")
    return decode(line.split(',2024-')[0])

# Process a chunk of lines
def process_chunk(chunk, multi_part_buffer, error_log):
    decoded_chunk = []
    i = 0
    while i < len(chunk):
        try:
            decoded = decode_message(chunk, i, multi_part_buffer)
            raw = chunk[i] if "2,1" not in chunk[i] else f"{chunk[i].split(',2024-')[0]} + {chunk[i + 1].split(',2024-')[0]}"
            decoded_chunk.append((decoded, raw))
            i += 2 if "2,1" in chunk[i] else 1
        except Exception as e:
            error_msg = f"Error decoding line {i + 1}: {chunk[i]} - {e}"
            print(error_msg)
            error_log.append(chunk[i])
            i += 1
    return decoded_chunk, multi_part_buffer, error_log

# %%
# Write to Parquet
def write_to_parquet(decoded_list, output_file):
    rows = []
    for decoded, raw in decoded_list:
        msg_type = decoded.msg_type
        mmsi = decoded.mmsi
        timestamp = raw.split(',2024-')[1] if ',2024-' in raw else 'N/A'
        row = {
            'msg_type': msg_type,
            'mmsi': mmsi,
            'lat': decoded.lat if msg_type in [1, 2, 3, 18] else None,
            'lon': decoded.lon if msg_type in [1, 2, 3, 18] else None,
            'speed': decoded.speed if msg_type in [1, 2, 3, 18] else None,
            'course': decoded.course if msg_type in [1, 2, 3, 18] else None,
            'vessel_name': getattr(decoded, 'name', 'N/A') if msg_type == 5 else None,
            'ship_type': getattr(decoded, 'ship_type', 'N/A') if msg_type == 5 else None,
            'timestamp': timestamp,
            'raw': raw
        }
        rows.append(row)
    
    # Convert to DataFrame
    df = pd.DataFrame(rows)
    
    # If file exists, append to it
    if os.path.exists(output_file):
        existing_df = pd.read_parquet(output_file)
        df = pd.concat([existing_df, df], ignore_index=True)
    
    # Write to parquet
    df.to_parquet(output_file, index=False)

# Summarize decoded messages
def summarize_decoded(decoded_list, section):
    print(f"\n=== {section} ===")
    msg_types = {}
    mmsi_set = set()
    for decoded, raw in decoded_list:
        msg_type = decoded.msg_type
        mmsi = decoded.mmsi
        msg_types[msg_type] = msg_types.get(msg_type, 0) + 1
        mmsi_set.add(mmsi)
        print(f"Type: {msg_type}, MMSI: {mmsi}, Raw: {raw.split(',2024-')[0]}")
        if msg_type in [1, 2, 3, 18]:
            print(f"  Lat: {decoded.lat}, Lon: {decoded.lon}, Speed: {decoded.speed}")
        elif msg_type == 5:
            print(f"  Vessel Name: {getattr(decoded, 'name', 'N/A')}, Ship Type: {getattr(decoded, 'ship_type', 'N/A')}")
    print(f"Message Types: {msg_types}")
    print(f"Unique MMSIs: {len(mmsi_set)}")

# %%
# Main processing
filename = "20240911_06053.txt"
output_file = "decoded_ais_data.parquet"
error_log_file = "ais_errors.txt"
chunk_size = 2000  # Increased to reduce split multi-part messages
multi_part_buffer = {}
error_log = []

# Read the file
with open(filename, 'r') as f:
    lines = [line.strip() for line in f.readlines() if line.strip()]
    total_lines = len(lines)
    print(f"Total lines in file: {total_lines}")

    all_decoded = []
    for start in range(0, total_lines, chunk_size):
        end = min(start + chunk_size, total_lines)
        chunk = lines[start:end]
        decoded_chunk, multi_part_buffer, error_log = process_chunk(chunk, multi_part_buffer, error_log)
        all_decoded.extend(decoded_chunk)
        write_to_parquet(decoded_chunk, output_file)
        
        if start == 0:
            summarize_decoded(decoded_chunk[:min(30, len(decoded_chunk))], "First 30 Lines")
        elif start <= total_lines // 2 < end:
            middle_start = max(0, (total_lines // 2) - start - 5)
            middle_end = min(middle_start + 10, len(decoded_chunk))
            summarize_decoded(decoded_chunk[middle_start:middle_end], "Middle Sample")
        if end == total_lines:
            summarize_decoded(decoded_chunk[-min(20, len(decoded_chunk)):], "Last 20 Lines")

# Write errors to log file
with open(error_log_file, 'w') as f:
    f.write("\n".join(error_log))

print(f"Decoding complete. Results saved to {output_file}. Errors logged to {error_log_file}")
# Out:
# Total lines in file: 364186
# Error decoding line 1275: !AIVDM,1,1,,A,,0*26,2024-09-11 00:06:15 - Empty or malformed payload
#
# === First 30 Lines ===
# Type: 1, MMSI: 538011058, Raw: !AIVDM,1,1,,B,1815UdP000Ld<0aj<F76cC5f0@Q6,0*49
#   Lat: -24.12966, Lon: -46.271113, Speed: 0.0
# Type: 1, MMSI: 710003185, Raw: !AIVDM,1,1,,A,1:U79tHP00LcesOjEcbWdOwf26sd,0*3C
#   Lat: -23.874703, Lon: -46.373788, Speed: 0.0
# Type: 1, MMSI: 538010074, Raw: !AIVDM,1,1,,A,1815QnP00pLd5bGjAP?ijA;R00RU,0*64
#   Lat: -23.988802, Lon: -46.292782, Speed: 5.6
# Type: 1, MMSI: 636018551, Raw: !AIVDM,1,1,,B,19NSOMh2i;Ld1LijBk>tq:Kj0<3C,0*19
#   Lat: -23.953395, Lon: -46.30716, Speed: 7.5
# Type: 1, MMSI: 710028580, Raw: !AIVDM,1,1,,B,1:U8e90P00Ld6EejB@R6hwwj0<2u,0*04
#   Lat: -23.9682, Lon: -46.29047, Speed: 0.0
# Type: 1, MMSI: 375293000, Raw: !AIVDM,1,1,,A,15Ur4B0000Ld0o5jCGgVlmsd0HQV,0*07
#   Lat: -23.937817, Lon: -46.30917, Speed: 0.0
# Type: 1, MMSI: 710002542, Raw: !AIVDM,1,1,,A,1:U77KdP00LcvVAjCQGTQOwh0L3G,0*2B
#   Lat: -23.93371, Lon: -46.316893, Speed: 0.0
# Type: 1, MMSI: 1193047, Raw: !AIVDM,1,1,,A,1018lEwP00td197jC:ClNgwj2D1F,0*06
#   Lat: -23.943548, Lon: -46.308208, Speed: 0.0
# Type: 1, MMSI: 710033530, Raw: !AIVDM,1,1,,B,1:U90NPP1<Ld1@ijBlfLvwwf0@Qp,0*2E
#   Lat: -23.952758, Lon: -46.3078, Speed: 7.6
# Type: 5, MMSI: 563121300, Raw: !AIVDM,2,1,2,B,58I2<U82FRJ?UKKKOJ0D4LhF10Th5:222222221@K`pKF6E;0WThCU3lp4m4,0*0B + !AIVDM,2,2,2,B,p0DQ@H88880,2*78
#   Vessel Name: N/A, Ship Type: 80
# Type: 1, MMSI: 710003538, Raw: !AIVDM,1,1,,A,1:U7;D`P00Ld2AejBR0dU?wj00Rp,0*45
#   Lat: -23.960743, Lon: -46.304337, Speed: 0.0
# Type: 1, MMSI: 258914000, Raw: !AIVDM,1,1,,B,13nrnl0Oh6LceUIjEcqeT2Mj0<38,0*50
#   Lat: -23.874603, Lon: -46.374967, Speed: 0.6
# Type: 1, MMSI: 538009488, Raw: !AIVDM,1,1,,B,1815OT001@LcvSCj>EUSPjmh06sd,0*32
#   Lat: -24.07527, Lon: -46.317052, Speed: 8.0
# Type: 1, MMSI: 229161000, Raw: !AIVDM,1,1,,B,13JRp:0000Ld6HwjB@msoTt00HRm,0*1A
#   Lat: -23.968068, Lon: -46.290295, Speed: 0.0
# Type: 18, MMSI: 710000650, Raw: !AIVDM,1,1,,A,B:U702P007;0CRtThmTdhSuP2h06,0*14
#   Lat: -23.946518, Lon: -46.307938, Speed: 0.0
# Type: 1, MMSI: 563121300, Raw: !AIVDM,1,1,,B,18I2<U30@:Lb;GMiJ4bbt9mf080;,0*0A
#   Lat: -25.502437, Lon: -46.710217, Speed: 1.0
# Type: 1, MMSI: 710100009, Raw: !AIVDM,1,1,,B,1:U=4:@P02td4OejBP4v4?v220R`,0*11
#   Lat: -23.961568, Lon: -46.296763, Speed: 0.2
# Type: 1, MMSI: 710006060, Raw: !AIVDM,1,1,,B,1:U7E;0P00td6P5jB=Le6wv420SC,0*3C
#   Lat: -23.969517, Lon: -46.289917, Speed: 0.0
# Type: 1, MMSI: 710002850, Raw: !AIVDM,1,1,,A,1:U78`PP0qLd5dwjAOUAggv6282R,0*02
#   Lat: -23.989085, Lon: -46.292642, Speed: 5.7
# Type: 18, MMSI: 710006820, Raw: !AIVDM,1,1,,B,B:U7H9000G;1DPLTVJEGM5Q02h06,0*64
#   Lat: -23.964312, Lon: -46.29408, Speed: 0.1
# Type: 1, MMSI: 712204006, Raw: !AIVDM,1,1,,B,1:W=NqPP00td5HijBI6f4?v420R>,0*69
#   Lat: -23.964543, Lon: -46.29372, Speed: 0.0
# Type: 1, MMSI: 710024840, Raw: !AIVDM,1,1,,B,1:U8NR0P1<Ld1KOjBj;Lqwwj0Vsd,0*70
#   Lat: -23.953845, Lon: -46.307228, Speed: 7.6
# Type: 1, MMSI: 710032570, Raw: !AIVDM,1,1,,B,1:U8tfPP00td0PAjBnbncOv40`2=,0*1B
#   Lat: -23.951928, Lon: -46.310387, Speed: 0.0
# Type: 1, MMSI: 636014459, Raw: !AIVDM,1,1,,B,19NS?Nh00ULd3;qj<1mERD080<4l,0*28
#   Lat: -24.138312, Lon: -46.301233, Speed: 3.7
# Type: 1, MMSI: 710006591, Raw: !AIVDM,1,1,,A,1:U7G?hP15tcemOjDOAuPgv82400,0*71
#   Lat: -23.907295, Lon: -46.374108, Speed: 6.9
# Type: 1, MMSI: 710007176, Raw: !AIVDM,1,1,,A,1:U7IR8000Ld2VgjBOoJB7280400,0*4E
#   Lat: -23.961658, Lon: -46.303215, Speed: 0.0
# Type: 1, MMSI: 710007151, Raw: !AIVDM,1,1,,A,1:U7IKpP12tcfgejDAO<SOv82@30,0*22
#   Lat: -23.91318, Lon: -46.371003, Speed: 6.6
# Type: 1, MMSI: 538010074, Raw: !AIVDM,1,1,,B,1815QnP00pLd5eMjAPaAei7l0H3R,0*17
#   Lat: -23.988632, Lon: -46.292617, Speed: 5.6
# Type: 3, MMSI: 636013612, Raw: !AIVDM,1,1,,B,39NS<;5000Ld66MjAeVP`mr>0DlJ,0*0E
#   Lat: -23.983103, Lon: -46.291283, Speed: 0.0
# Type: 18, MMSI: 710013290, Raw: !AIVDM,1,1,,A,B:U7iJP0>o;0dFLTF2hcDRS00@49,0*68
#   Lat: -23.992247, Lon: -46.302647, Speed: 5.9
# Message Types: {1: 25, 5: 1, 18: 3, 3: 1}
# Unique MMSIs: 28
# Error decoding line 1752: !AIVDM,1,1,,A,,0*26,2024-09-11 01:34:59 - Empty or malformed payload
# Error decoding line 345: !AIVDM,1,1,,A,,0*26,2024-09-11 04:21:02 - Empty or malformed payload
# Error decoding line 348: !AIVDM,1,1,,A,,0*26,2024-09-11 04:21:03 - Empty or malformed payload
# Error decoding line 399: !AIVDM,1,1,,B,,0*25,2024-09-11 04:21:17 - Empty or malformed payload
# Error decoding line 410: !AIVDM,1,1,,B,,0*25,2024-09-11 04:21:25 - Empty or malformed payload
# Error decoding line 552: !AIVDM,1,1,,A,,0*26,2024-09-11 04:22:02 - Empty or malformed payload
# Error decoding line 2000: !AIVDM,2,1,5,A,58155;T2>BBEKLhK:20p5HTu>1HE8lThTtr22217H14D<6Dc0MPTTln`8888,0*5D,2024-09-11 06:03:15 - Missing second part
# Error decoding line 946: !AIVDM,1,1,,A,,0*26,2024-09-11 07:45:09 - Empty or malformed payload
# Error decoding line 320: !AIVDM,1,1,,B,,0*25,2024-09-11 09:13:15 - Empty or malformed payload
# Error decoding line 370: !AIVDM,1,1,,B,,0*25,2024-09-11 09:20:28 - Empty or malformed payload
# Error decoding line 906: !AIVDM,1,1,,B,,0*25,2024-09-11 09:22:18 - Empty or malformed payload
# Error decoding line 884: !AIVDM,1,1,,B,,0*25,2024-09-11 09:29:23 - Empty or malformed payload
# Error decoding line 1113: !AIVDM,1,1,,B,,0*25,2024-09-11 09:30:11 - Empty or malformed payload
# Error decoding line 1160: !AIVDM,1,1,,B,,0*25,2024-09-11 09:30:20 - Empty or malformed payload
# Error decoding line 1758: !AIVDM,1,1,,B,,0*25,2024-09-11 09:32:17 - Empty or malformed payload
# Error decoding line 1795: !AIVDM,1,1,,B,,0*25,2024-09-11 09:32:27 - Empty or malformed payload
# Error decoding line 1166: !AIVDM,1,1,,B,,0*25,2024-09-11 09:37:18 - Empty or malformed payload
# Error decoding line 1716: !AIVDM,1,1,,B,,0*25,2024-09-11 09:39:15 - Empty or malformed payload
# Error decoding line 1752: !AIVDM,1,1,,B,,0*25,2024-09-11 09:39:25 - Empty or malformed payload
# Error decoding line 2000: !AIVDM,2,1,7,B,53nwCv42Dd8HhP=G>20pu8l4pB0l5PTmE>22221671rB?6Bm0DhTTln`8888,0*56,2024-09-11 10:01:47 - Missing second part
# Error decoding line 405: !AIVDM,1,1,,B,,0*25,2024-09-11 10:03:08 - Empty or malformed payload
# Error decoding line 498: !AIVDM,1,1,,B,,0*25,2024-09-11 10:03:31 - Empty or malformed payload
# Error decoding line 731: !AIVDM,1,1,,B,,0*25,2024-09-11 10:04:18 - Empty or malformed payload
# Error decoding line 1284: !AIVDM,1,1,,B,,0*25,2024-09-11 10:06:18 - Empty or malformed payload
# Error decoding line 1524: !AIVDM,1,1,,B,,0*25,2024-09-11 10:07:10 - Empty or malformed payload
# Error decoding line 1993: !AIVDM,1,1,,B,,0*25,2024-09-11 10:08:51 - Empty or malformed payload
# Error decoding line 383: !AIVDM,1,1,,B,,0*25,2024-09-11 10:10:15 - Empty or malformed payload
# Error decoding line 1721: !AIVDM,1,1,,B,,0*25,2024-09-11 10:15:12 - Empty or malformed payload
# Error decoding line 2000: !AIVDM,2,1,5,A,53lr@F82GaEKTP7GWS0<l60<Ln10585AT0000017<;gOD6G40S@TTlnP0000,0*61,2024-09-11 11:17:46 - Missing second part
# Error decoding line 1425: !AIVDM,1,1,,B,,0*25,2024-09-11 11:45:18 - Empty or malformed payload
# Error decoding line 1480: !AIVDM,1,1,,A,,0*26,2024-09-11 11:45:30 - Empty or malformed payload
# Error decoding line 1711: !AIVDM,1,1,,B,,0*25,2024-09-11 11:46:14 - Empty or malformed payload
# Error decoding line 1730: !AIVDM,1,1,,B,,0*25,2024-09-11 11:46:21 - Empty or malformed payload
# Error decoding line 1964: !AIVDM,1,1,,B,,0*25,2024-09-11 11:47:13 - Empty or malformed payload
# Error decoding line 1987: !AIVDM,1,1,,B,,0*25,2024-09-11 11:47:18 - Empty or malformed payload
# Error decoding line 1991: !AIVDM,1,1,,B,,0*25,2024-09-11 11:47:18 - Empty or malformed payload
# Error decoding line 1995: !AIVDM,1,1,,B,,0*25,2024-09-11 11:47:18 - Empty or malformed payload
# Error decoding line 2000: !AIVDM,1,1,,B,,0*25,2024-09-11 11:47:18 - Empty or malformed payload
# Error decoding line 278: !AIVDM,1,1,,B,,0*25,2024-09-11 11:48:18 - Empty or malformed payload
# Error decoding line 281: !AIVDM,1,1,,B,,0*25,2024-09-11 11:48:18 - Empty or malformed payload
# Error decoding line 531: !AIVDM,1,1,,B,,0*25,2024-09-11 11:49:10 - Empty or malformed payload
# Error decoding line 588: !AIVDM,1,1,,B,,0*25,2024-09-11 11:49:21 - Empty or malformed payload
# Error decoding line 847: !AIVDM,1,1,,B,,0*25,2024-09-11 11:50:14 - Empty or malformed payload
# Error decoding line 850: !AIVDM,1,1,,B,,0*25,2024-09-11 11:50:14 - Empty or malformed payload
# Error decoding line 1124: !AIVDM,1,1,,B,,0*25,2024-09-11 11:51:21 - Empty or malformed payload
# Error decoding line 1229: !AIVDM,1,1,,B,,0*25,2024-09-11 11:51:45 - Empty or malformed payload
# Error decoding line 1383: !AIVDM,1,1,,B,,0*25,2024-09-11 11:52:17 - Empty or malformed payload
# Error decoding line 1597: !AIVDM,1,1,,B,,0*25,2024-09-11 11:53:10 - Empty or malformed payload
# Error decoding line 1858: !AIVDM,1,1,,A,,0*26,2024-09-11 11:54:09 - Empty or malformed payload
# Error decoding line 1862: !AIVDM,1,1,,B,,0*25,2024-09-11 11:54:09 - Empty or malformed payload
# Error decoding line 1880: !AIVDM,1,1,,B,,0*25,2024-09-11 11:54:14 - Empty or malformed payload
#
# === Middle Sample ===
# Type: 1, MMSI: 304053000, Raw: !AIVDM,1,1,,B,14Qus203@hLcrfajCgb:wpn<05P<,0*1E
#   Lat: -23.927613, Lon: -46.3301, Speed: 4.8
# Type: 1, MMSI: 710003185, Raw: !AIVDM,1,1,,B,1:U79tHP00Ld0l?jCGOVDwv:2D3@,0*5F
#   Lat: -23.937923, Lon: -46.309322, Speed: 0.0
# Type: 1, MMSI: 375293000, Raw: !AIVDM,1,1,,B,15Ur4B0000Ld0o5jCGUmU5F600Rv,0*50
#   Lat: -23.937882, Lon: -46.30917, Speed: 0.0
# Type: 1, MMSI: 710002542, Raw: !AIVDM,1,1,,B,1:U77KdP00LctegjCUjLbOv<0846,0*6A
#   Lat: -23.931825, Lon: -46.323322, Speed: 0.0
# Type: 1, MMSI: 538011058, Raw: !AIVDM,1,1,,A,1815UdP001Ld<4kj<C?coif:05P<,0*4A
#   Lat: -24.130883, Lon: -46.270892, Speed: 0.1
# Type: 1, MMSI: 720001258, Raw: !AIVDM,1,1,,A,1:faHrPP00tcuNmjCkv>4?v>2D4K,0*11
#   Lat: -23.925773, Lon: -46.320703, Speed: 0.0
# Type: 1, MMSI: 710028580, Raw: !AIVDM,1,1,,A,1:U8e90P0lLcoqmjCutt2wv@0L3J,0*56
#   Lat: -23.921515, Lon: -46.339743, Speed: 5.2
# Type: 3, MMSI: 538008846, Raw: !AIVDM,1,1,,A,3815M3U000Ld6pUjB86kLJT80Dg:,0*07
#   Lat: -23.971795, Lon: -46.28861, Speed: 0.0
# Type: 1, MMSI: 563051800, Raw: !AIVDM,1,1,,B,18Huu6000nLd6ESjB1GuBJb@0H4s,0*3A
#   Lat: -23.974668, Lon: -46.290478, Speed: 5.4
# Type: 1, MMSI: 710033530, Raw: !AIVDM,1,1,,A,1:U90NPP00Ld4w7jAApEFgv<085@,0*2A
#   Lat: -23.994932, Lon: -46.295088, Speed: 0.0
# Message Types: {1: 9, 3: 1}
# Unique MMSIs: 10
# Error decoding line 156: !AIVDM,1,1,,B,,0*25,2024-09-11 12:27:16 - Empty or malformed payload
# Error decoding line 203: !AIVDM,1,1,,B,,0*25,2024-09-11 12:27:30 - Empty or malformed payload
# Error decoding line 1795: !AIVDM,1,1,,B,,0*25,2024-09-11 12:34:20 - Empty or malformed payload
# Error decoding line 9: !AIVDM,1,1,,B,,0*25,2024-09-11 12:35:18 - Empty or malformed payload
# Error decoding line 222: !AIVDM,1,1,,B,,0*25,2024-09-11 12:36:13 - Empty or malformed payload
# Error decoding line 470: !AIVDM,1,1,,B,,0*25,2024-09-11 12:37:15 - Empty or malformed payload
# Error decoding line 931: !AIVDM,1,1,,B,,0*25,2024-09-11 12:39:09 - Empty or malformed payload
# Error decoding line 959: !AIVDM,1,1,,B,,0*25,2024-09-11 12:39:17 - Empty or malformed payload
# Error decoding line 527: !AIVDM,1,1,,A,,0*26,2024-09-11 12:45:04 - Empty or malformed payload
# Error decoding line 1899: !AIVDM,1,1,,B,,0*25,2024-09-11 12:50:18 - Empty or malformed payload
# Error decoding line 2000: !AIVDM,2,1,2,A,59NSb402Ba0SDh@;V21:1<eUL4hdE:2222222216CPE<A6C90GwPT`4ln`88,0*4E,2024-09-11 12:50:41 - Missing second part
# Error decoding line 50: !AIVDM,1,1,,B,,0*25,2024-09-11 12:50:53 - Empty or malformed payload
# Error decoding line 1959: !AIVDM,1,1,,B,,0*25,2024-09-11 12:58:16 - Empty or malformed payload
# Error decoding line 1111: !AIVDM,1,1,,B,,0*25,2024-09-11 13:10:15 - Empty or malformed payload
# Error decoding line 1332: !AIVDM,1,1,,A,,0*26,2024-09-11 13:11:13 - Empty or malformed payload
# Error decoding line 190: !AIVDM,1,1,,A,,0*26,2024-09-11 13:22:11 - Empty or malformed payload
# Error decoding line 1953: !AIVDM,1,1,,B,,0*25,2024-09-11 13:29:20 - Empty or malformed payload
# Error decoding line 755: !AIVDM,1,1,,B,,0*25,2024-09-11 13:32:32 - Empty or malformed payload
# Error decoding line 1286: !AIVDM,1,1,,A,,0*26,2024-09-11 13:34:30 - Empty or malformed payload
# Error decoding line 1677: !AIVDM,1,1,,A,,0*26,2024-09-11 13:36:00 - Empty or malformed payload
# Error decoding line 1738: !AIVDM,1,1,,B,,0*25,2024-09-11 13:36:14 - Empty or malformed payload
# Error decoding line 782: !AIVDM,1,1,,A,,0*26,2024-09-11 13:40:11 - Empty or malformed payload
# Error decoding line 1762: !AIVDM,1,1,,A,,0*26,2024-09-11 13:43:59 - Empty or malformed payload
# Error decoding line 1864: !AIVDM,1,1,,B,,0*25,2024-09-11 13:44:21 - Empty or malformed payload
# Error decoding line 771: !AIVDM,1,1,,A,,0*26,2024-09-11 13:55:32 - Empty or malformed payload
# Error decoding line 1185: !AIVDM,1,1,,A,,0*26,2024-09-11 13:57:08 - Empty or malformed payload
# Error decoding line 1277: !AIVDM,1,1,,A,,0*26,2024-09-11 13:57:30 - Empty or malformed payload
# Error decoding line 1897: !AIVDM,1,1,,A,,0*26,2024-09-11 14:00:00 - Empty or malformed payload
# Error decoding line 1258: !AIVDM,1,1,,A,,0*26,2024-09-11 14:05:31 - Empty or malformed payload
# Error decoding line 1928: !AIVDM,1,1,,B,,0*25,2024-09-11 14:08:15 - Empty or malformed payload
# Error decoding line 1947: !AIVDM,1,1,,B,,0*25,2024-09-11 14:08:18 - Empty or malformed payload
# Error decoding line 1145: !AIVDM,1,1,,A,,0*26,2024-09-11 14:36:28 - Empty or malformed payload
# Error decoding line 1978: !AIVDM,1,1,,A,,0*26,2024-09-11 14:40:03 - Empty or malformed payload
# Error decoding line 1513: !AIVDM,1,1,,A,,0*26,2024-09-11 14:46:09 - Empty or malformed payload
# Error decoding line 1612: !AIVDM,1,1,,A,,0*26,2024-09-11 14:46:34 - Empty or malformed payload
# Error decoding line 1798: !AIVDM,1,1,,B,,0*25,2024-09-11 14:47:16 - Empty or malformed payload
# Error decoding line 18: !AIVDM,1,1,,A,,0*26,2024-09-11 14:48:09 - Empty or malformed payload
# Error decoding line 1003: !AIVDM,1,1,,A,,0*26,2024-09-11 14:52:10 - Empty or malformed payload
# Error decoding line 1048: !AIVDM,1,1,,B,,0*25,2024-09-11 14:52:18 - Empty or malformed payload
# Error decoding line 2000: !AIVDM,2,1,8,A,5:U8lO42CdG@4;72221M>10th58U>2222222220l1P<656Ef0>4hCU3lsll8,0*3C,2024-09-11 15:11:43 - Missing second part
# Error decoding line 325: !AIVDM,1,1,,A,,0*26,2024-09-11 15:13:00 - Empty or malformed payload
# Error decoding line 1955: !AIVDM,1,1,,A,,0*26,2024-09-11 15:35:58 - Empty or malformed payload
# Error decoding line 2000: !AIVDM,2,1,6,B,5815DwH2=3V5KM8KB20HD@E84j0eDl4pv2222216EPL8@6D?0J0TTln`8888,0*59,2024-09-11 15:36:09 - Missing second part
# Error decoding line 370: !AIVDM,1,1,,A,,0*26,2024-09-11 15:37:32 - Empty or malformed payload
# Error decoding line 1040: !AIVDM,1,1,,A,,0*26,2024-09-11 15:48:00 - Empty or malformed payload
# Error decoding line 1872: !AIVDM,1,1,,A,,0*26,2024-09-11 15:51:28 - Empty or malformed payload
# Error decoding line 460: !AIVDM,1,1,,A,,0*26,2024-09-11 15:54:02 - Empty or malformed payload
# Error decoding line 569: !AIVDM,1,1,,A,,0*26,2024-09-11 15:54:30 - Empty or malformed payload
# Error decoding line 1475: !AIVDM,1,1,,A,,0*26,2024-09-11 15:58:10 - Empty or malformed payload
# Error decoding line 853: !AIVDM,1,1,,A,,0*26,2024-09-11 16:19:08 - Empty or malformed payload
# Error decoding line 1377: !AIVDM,1,1,,A,,0*26,2024-09-11 16:21:10 - Empty or malformed payload
# Error decoding line 417: !AIVDM,1,1,,A,,0*26,2024-09-11 16:25:02 - Empty or malformed payload
# Error decoding line 669: !AIVDM,1,1,,A,,0*26,2024-09-11 16:34:02 - Empty or malformed payload
# Error decoding line 1595: !AIVDM,1,1,,B,,0*25,2024-09-11 16:45:19 - Empty or malformed payload
# Error decoding line 1226: !AIVDM,1,1,,A,,0*26,2024-09-11 17:00:05 - Empty or malformed payload
# Error decoding line 250: !AIVDM,1,1,,B,,0*25,2024-09-11 17:04:16 - Empty or malformed payload
# Error decoding line 742: !AIVDM,1,1,,B,,0*25,2024-09-11 17:06:17 - Empty or malformed payload
# Error decoding line 747: !AIVDM,1,1,,B,,0*25,2024-09-11 17:06:17 - Empty or malformed payload
# Error decoding line 801: !AIVDM,1,1,,B,,0*25,2024-09-11 17:06:29 - Empty or malformed payload
# Error decoding line 1237: !AIVDM,1,1,,B,,0*25,2024-09-11 17:08:16 - Empty or malformed payload
# Error decoding line 1500: !AIVDM,1,1,,B,,0*25,2024-09-11 17:32:29 - Empty or malformed payload
# Error decoding line 1689: !AIVDM,1,1,,B,,0*25,2024-09-11 17:33:13 - Empty or malformed payload
# Error decoding line 1957: !AIVDM,1,1,,B,,0*25,2024-09-11 17:34:09 - Empty or malformed payload
# Error decoding line 2: !AIVDM,1,1,,B,,0*25,2024-09-11 17:34:21 - Empty or malformed payload
# Error decoding line 520: !AIVDM,1,1,,B,,0*25,2024-09-11 17:36:16 - Empty or malformed payload
# Error decoding line 524: !AIVDM,1,1,,B,,0*25,2024-09-11 17:36:17 - Empty or malformed payload
# Error decoding line 574: !AIVDM,1,1,,B,,0*25,2024-09-11 17:36:28 - Empty or malformed payload
# Error decoding line 753: !AIVDM,1,1,,B,,0*25,2024-09-11 17:37:11 - Empty or malformed payload
# Error decoding line 777: !AIVDM,1,1,,B,,0*25,2024-09-11 17:37:17 - Empty or malformed payload
# Error decoding line 784: !AIVDM,1,1,,B,,0*25,2024-09-11 17:37:17 - Empty or malformed payload
# Error decoding line 812: !AIVDM,1,1,,B,,0*25,2024-09-11 17:37:26 - Empty or malformed payload
# Error decoding line 979: !AIVDM,1,1,,B,,0*25,2024-09-11 17:38:10 - Empty or malformed payload
# Error decoding line 1015: !AIVDM,1,1,,B,,0*25,2024-09-11 17:38:15 - Empty or malformed payload
# Error decoding line 1265: !AIVDM,1,1,,B,,0*25,2024-09-11 17:39:18 - Empty or malformed payload
# Error decoding line 1539: !AIVDM,1,1,,B,,0*25,2024-09-11 17:40:17 - Empty or malformed payload
# Error decoding line 1556: !AIVDM,1,1,,B,,0*25,2024-09-11 17:40:22 - Empty or malformed payload
# Error decoding line 1558: !AIVDM,1,1,,B,,0*25,2024-09-11 17:40:22 - Empty or malformed payload
# Error decoding line 48: !AIVDM,1,1,,B,,0*25,2024-09-11 17:42:14 - Empty or malformed payload
# Error decoding line 338: !AIVDM,1,1,,B,,0*25,2024-09-11 17:43:19 - Empty or malformed payload
# Error decoding line 593: !AIVDM,1,1,,B,,0*25,2024-09-11 17:44:18 - Empty or malformed payload
# Error decoding line 849: !AIVDM,1,1,,B,,0*25,2024-09-11 17:45:11 - Empty or malformed payload
# Error decoding line 879: !AIVDM,1,1,,B,,0*25,2024-09-11 17:45:15 - Empty or malformed payload
# Error decoding line 885: !AIVDM,1,1,,B,,0*25,2024-09-11 17:45:15 - Empty or malformed payload
# Error decoding line 1043: !AIVDM,1,1,,B,,0*25,2024-09-11 17:45:50 - Empty or malformed payload
# Error decoding line 1142: !AIVDM,1,1,,B,,0*25,2024-09-11 17:46:08 - Empty or malformed payload
# Error decoding line 1186: !AIVDM,1,1,,B,,0*25,2024-09-11 17:46:21 - Empty or malformed payload
# Error decoding line 1450: !AIVDM,1,1,,B,,0*25,2024-09-11 17:47:15 - Empty or malformed payload
# Error decoding line 1469: !AIVDM,1,1,,B,,0*25,2024-09-11 17:47:21 - Empty or malformed payload
# Error decoding line 1619: !AIVDM,1,1,,B,,0*25,2024-09-11 17:47:49 - Empty or malformed payload
# Error decoding line 1749: !AIVDM,1,1,,B,,0*25,2024-09-11 17:48:16 - Empty or malformed payload
# Error decoding line 1891: !AIVDM,1,1,,B,,0*25,2024-09-11 17:48:44 - Empty or malformed payload
# Error decoding line 80: !AIVDM,1,1,,A,,0*26,2024-09-11 17:49:31 - Empty or malformed payload
# Error decoding line 260: !AIVDM,1,1,,B,,0*25,2024-09-11 17:50:15 - Empty or malformed payload
# Error decoding line 480: !AIVDM,1,1,,A,,0*26,2024-09-11 17:51:09 - Empty or malformed payload
# Error decoding line 518: !AIVDM,1,1,,B,,0*25,2024-09-11 17:51:17 - Empty or malformed payload
# Error decoding line 770: !AIVDM,1,1,,B,,0*25,2024-09-11 17:52:17 - Empty or malformed payload
# Error decoding line 1018: !AIVDM,1,1,,B,,0*25,2024-09-11 17:53:17 - Empty or malformed payload
# Error decoding line 1293: !AIVDM,1,1,,B,,0*25,2024-09-11 17:54:16 - Empty or malformed payload
# Error decoding line 1507: !AIVDM,1,1,,A,,0*26,2024-09-11 17:55:12 - Empty or malformed payload
# Error decoding line 29: !AIVDM,1,1,,B,,0*25,2024-09-11 17:57:13 - Empty or malformed payload
# Error decoding line 262: !AIVDM,1,1,,B,,0*25,2024-09-11 17:58:08 - Empty or malformed payload
# Error decoding line 330: !AIVDM,1,1,,B,,0*25,2024-09-11 17:58:26 - Empty or malformed payload
# Error decoding line 470: !AIVDM,1,1,,A,,0*26,2024-09-11 17:59:01 - Empty or malformed payload
# Error decoding line 666: !AIVDM,1,1,,B,,0*25,2024-09-11 17:59:46 - Empty or malformed payload
# Error decoding line 1048: !AIVDM,1,1,,B,,0*25,2024-09-11 18:01:20 - Empty or malformed payload
# Error decoding line 1049: !AIVDM,1,1,,B,,0*25,2024-09-11 18:01:20 - Empty or malformed payload
# Error decoding line 1052: !AIVDM,1,1,,B,,0*25,2024-09-11 18:01:20 - Empty or malformed payload
# Error decoding line 1062: !AIVDM,1,1,,B,,0*25,2024-09-11 18:01:20 - Empty or malformed payload
# Error decoding line 1078: !AIVDM,1,1,,B,,0*25,2024-09-11 18:01:26 - Empty or malformed payload
# Error decoding line 1105: !AIVDM,1,1,,B,,0*25,2024-09-11 18:01:32 - Empty or malformed payload
# Error decoding line 1164: !AIVDM,1,1,,B,,0*25,2024-09-11 18:01:45 - Empty or malformed payload
# Error decoding line 1265: !AIVDM,1,1,,B,,0*25,2024-09-11 18:02:10 - Empty or malformed payload
# Error decoding line 1292: !AIVDM,1,1,,B,,0*25,2024-09-11 18:02:15 - Empty or malformed payload
# Error decoding line 1304: !AIVDM,1,1,,B,,0*25,2024-09-11 18:02:20 - Empty or malformed payload
# Error decoding line 1354: !AIVDM,1,1,,B,,0*25,2024-09-11 18:02:30 - Empty or malformed payload
# Error decoding line 1423: !AIVDM,1,1,,B,,0*25,2024-09-11 18:02:46 - Empty or malformed payload
# Error decoding line 1525: !AIVDM,1,1,,B,,0*25,2024-09-11 18:03:11 - Empty or malformed payload
# Error decoding line 1553: !AIVDM,1,1,,B,,0*25,2024-09-11 18:03:16 - Empty or malformed payload
# Error decoding line 1818: !AIVDM,1,1,,B,,0*25,2024-09-11 18:04:17 - Empty or malformed payload
# Error decoding line 1853: !AIVDM,1,1,,B,,0*25,2024-09-11 18:04:23 - Empty or malformed payload
# Error decoding line 1875: !AIVDM,1,1,,B,,0*25,2024-09-11 18:04:29 - Empty or malformed payload
# Error decoding line 71: !AIVDM,1,1,,B,,0*25,2024-09-11 18:05:20 - Empty or malformed payload
# Error decoding line 186: !AIVDM,1,1,,B,,0*25,2024-09-11 18:05:47 - Empty or malformed payload
# Error decoding line 314: !AIVDM,1,1,,B,,0*25,2024-09-11 18:06:15 - Empty or malformed payload
# Error decoding line 623: !AIVDM,1,1,,B,,0*25,2024-09-11 18:07:31 - Empty or malformed payload
# Error decoding line 1070: !AIVDM,1,1,,B,,0*25,2024-09-11 18:09:14 - Empty or malformed payload
# Error decoding line 1073: !AIVDM,1,1,,B,,0*25,2024-09-11 18:09:14 - Empty or malformed payload
# Error decoding line 1081: !AIVDM,1,1,,B,,0*25,2024-09-11 18:09:19 - Empty or malformed payload
# Error decoding line 1228: !AIVDM,1,1,,B,,0*25,2024-09-11 18:09:52 - Empty or malformed payload
# Error decoding line 1334: !AIVDM,1,1,,B,,0*25,2024-09-11 18:10:16 - Empty or malformed payload
# Error decoding line 780: !AIVDM,1,1,,B,,0*25,2024-09-11 18:16:19 - Empty or malformed payload
# Error decoding line 1258: !AIVDM,1,1,,B,,0*25,2024-09-11 18:18:16 - Empty or malformed payload
# Error decoding line 1980: !AIVDM,1,1,,B,,0*25,2024-09-11 18:21:17 - Empty or malformed payload
# Error decoding line 503: !AIVDM,1,1,,A,,0*26,2024-09-11 18:23:29 - Empty or malformed payload
# Error decoding line 731: !AIVDM,1,1,,B,,0*25,2024-09-11 18:24:29 - Empty or malformed payload
# Error decoding line 925: !AIVDM,1,1,,B,,0*25,2024-09-11 18:25:19 - Empty or malformed payload
# Error decoding line 1824: !AIVDM,1,1,,A,,0*26,2024-09-11 18:28:59 - Empty or malformed payload
# Error decoding line 368: !AIVDM,1,1,,B,,0*25,2024-09-11 18:31:12 - Empty or malformed payload
# Error decoding line 732: !AIVDM,1,1,,A,,0*26,2024-09-11 18:41:04 - Empty or malformed payload
# Error decoding line 1913: !AIVDM,1,1,,B,,0*25,2024-09-11 18:45:17 - Empty or malformed payload
# Error decoding line 210: !AIVDM,1,1,,B,,0*25,2024-09-11 18:46:17 - Empty or malformed payload
# Error decoding line 1862: !AIVDM,1,1,,B,,0*25,2024-09-11 18:52:12 - Empty or malformed payload
# Error decoding line 235: !AIVDM,1,1,,B,,0*25,2024-09-11 18:53:33 - Empty or malformed payload
# Error decoding line 1139: !AIVDM,1,1,,B,,0*25,2024-09-11 19:03:50 - Empty or malformed payload
# Error decoding line 1346: !AIVDM,1,1,,B,,0*25,2024-09-11 19:12:15 - Empty or malformed payload
# Error decoding line 2000: !AIVDM,2,1,4,B,5:U7IKp2HS5a13O33L1=HUA`E:18t<P610DA8t0l1H<56tf70=lhCU3lh000,0*76,2024-09-11 19:14:40 - Missing second part
# Error decoding line 461: !AIVDM,1,1,,B,,0*25,2024-09-11 19:24:11 - Empty or malformed payload
# Error decoding line 1728: !AIVDM,1,1,,B,,0*25,2024-09-11 20:56:15 - Empty or malformed payload
# Error decoding line 1983: !AIVDM,1,1,,B,,0*25,2024-09-11 20:57:16 - Empty or malformed payload
# Error decoding line 1989: !AIVDM,1,1,,B,,0*25,2024-09-11 20:57:17 - Empty or malformed payload
# Error decoding line 700: !AIVDM,1,1,,B,,0*25,2024-09-11 20:59:50 - Empty or malformed payload
# Error decoding line 832: !AIVDM,1,1,,B,,0*25,2024-09-11 21:00:21 - Empty or malformed payload
# Error decoding line 1019: !AIVDM,1,1,,A,,0*26,2024-09-11 21:01:00 - Empty or malformed payload
# Error decoding line 1081: !AIVDM,1,1,,B,,0*25,2024-09-11 21:01:18 - Empty or malformed payload
# Error decoding line 2000: !AIVDM,2,1,1,B,59NRuaT2:<n<Di1SN20u84pLF1L5HF2222222216>0e<>6E;0@@T`4ln`888,0*2B,2024-09-11 21:12:51 - Missing second part
# Error decoding line 98: !AIVDM,1,1,,B,,0*25,2024-09-11 21:13:17 - Empty or malformed payload
# Error decoding line 376: !AIVDM,1,1,,B,,0*25,2024-09-11 21:14:19 - Empty or malformed payload
# Error decoding line 1769: !AIVDM,1,1,,B,,0*25,2024-09-11 21:19:28 - Empty or malformed payload
# Error decoding line 218: !AIVDM,1,1,,B,,0*25,2024-09-11 21:21:09 - Empty or malformed payload
# Error decoding line 1041: !AIVDM,1,1,,B,,0*25,2024-09-11 21:24:16 - Empty or malformed payload
# Error decoding line 1903: !AIVDM,1,1,,B,,0*25,2024-09-11 21:42:52 - Empty or malformed payload
# Error decoding line 282: !AIVDM,1,1,,B,,0*25,2024-09-11 21:44:20 - Empty or malformed payload
# Error decoding line 401: !AIVDM,1,1,,B,,0*25,2024-09-11 21:44:50 - Empty or malformed payload
# Error decoding line 1022: !AIVDM,1,1,,B,,0*25,2024-09-11 21:47:20 - Empty or malformed payload
# Error decoding line 1291: !AIVDM,1,1,,B,,0*25,2024-09-11 21:48:20 - Empty or malformed payload
# Error decoding line 1327: !AIVDM,1,1,,B,,0*25,2024-09-11 21:48:32 - Empty or malformed payload
# Error decoding line 1456: !AIVDM,1,1,,A,,0*26,2024-09-11 21:49:00 - Empty or malformed payload
# Error decoding line 1700: !AIVDM,1,1,,A,,0*26,2024-09-11 21:50:01 - Empty or malformed payload
# Error decoding line 1823: !AIVDM,1,1,,B,,0*25,2024-09-11 21:50:28 - Empty or malformed payload
# Error decoding line 54: !AIVDM,1,1,,B,,0*25,2024-09-11 21:51:19 - Empty or malformed payload
# Error decoding line 168: !AIVDM,1,1,,B,,0*25,2024-09-11 21:51:46 - Empty or malformed payload
# Error decoding line 833: !AIVDM,1,1,,B,,0*25,2024-09-11 21:54:16 - Empty or malformed payload
# Error decoding line 977: !AIVDM,1,1,,A,,0*26,2024-09-11 22:02:28 - Empty or malformed payload
# Error decoding line 1622: !AIVDM,1,1,,B,,0*25,2024-09-11 22:05:17 - Empty or malformed payload
# Error decoding line 1729: !AIVDM,1,1,,B,,0*25,2024-09-11 22:05:44 - Empty or malformed payload
# Error decoding line 1798: !AIVDM,1,1,,A,,0*26,2024-09-11 22:06:01 - Empty or malformed payload
# Error decoding line 1860: !AIVDM,1,1,,B,,0*25,2024-09-11 22:06:16 - Empty or malformed payload
# Error decoding line 857: !AIVDM,1,1,,B,,0*25,2024-09-11 22:10:19 - Empty or malformed payload
# Error decoding line 1900: !AIVDM,1,1,,A,mEEEOPBaAmBh800?;1JqLTFOI6CwUPR1OsieOeEEEGp4b@,4*44,2024-09-11 23:18:16 - The message AISSentence<!AIVDM,1,1,,A,mEEEOPBaAmBh800?;1JqLTFOI6CwUPR1OsieOeEEEGp4b@,4*44> is not supported!
#
# === Last 20 Lines ===
# Type: 3, MMSI: 712204006, Raw: !AIVDM,1,1,,A,3:W=NqPP01td0R9jCd?f4?wV20Ek,0*22
#   Lat: -23.92907, Lon: -46.310287, Speed: 0.1
# Type: 5, MMSI: 636092780, Raw: !AIVDM,2,1,2,A,59N`1K82@:MT7QI3V21@Dm04pu>2222222222216La7JC6@R0OhTTln`8888,0*4E + !AIVDM,2,2,2,A,88888888880,2*26
#   Vessel Name: N/A, Ship Type: 70
# Type: 1, MMSI: 710000350, Raw: !AIVDM,1,1,,A,1:U6voPP00tcwwQjCktRggwb20SG,0*76
#   Lat: -23.925783, Lon: -46.312133, Speed: 0.0
# Type: 1, MMSI: 710024840, Raw: !AIVDM,1,1,,A,1:U8NR0P00LcvR=jCQJ9dwwL0PRO,0*54
#   Lat: -23.933693, Lon: -46.31711, Speed: 0.0
# Type: 3, MMSI: 538005945, Raw: !AIVDM,1,1,,A,3815AfE000Ld4w=jB7vp>J7b0E4b,0*36
#   Lat: -23.971848, Lon: -46.295083, Speed: 0.0
# Type: 1, MMSI: 710007151, Raw: !AIVDM,1,1,,B,1:U7IKpP00td2MIjBP>N4?w`28O=,0*24
#   Lat: -23.961505, Lon: -46.303713, Speed: 0.0
# Type: 1, MMSI: 710032570, Raw: !AIVDM,1,1,,A,1:U8tfPP00Ld50gjAATCQ?w`0PSc,0*4C
#   Lat: -23.995065, Lon: -46.295002, Speed: 0.0
# Type: 3, MMSI: 477833300, Raw: !AIVDM,1,1,,B,377d`E0Oh@Ld01ojCAuQUjwV00pP,0*34
#   Lat: -23.940283, Lon: -46.312008, Speed: 1.6
# Type: 1, MMSI: 710032570, Raw: !AIVDM,1,1,,A,1:U8tfPP00Ld50gjAATCQ?w`0PSc,0*4C
#   Lat: -23.995065, Lon: -46.295002, Speed: 0.0
# Type: 1, MMSI: 710030460, Raw: !AIVDM,1,1,,A,1:U8lO0P00Ld5S=jAIHWuOwd0@OJ,0*51
#   Lat: -23.99173, Lon: -46.293163, Speed: 0.0
# Type: 3, MMSI: 314481000, Raw: !AIVDM,1,1,,B,34crIJ0000Ld6B5jAl?9nUu`04kS,0*0A
#   Lat: -23.980273, Lon: -46.290663, Speed: 0.0
# Type: 3, MMSI: 372240000, Raw: !AIVDM,1,1,,B,35RwfP1001Ld;OEj=kRFa1qP0Dg:,0*59
#   Lat: -24.089798, Lon: -46.27289, Speed: 0.1
# Type: 1, MMSI: 710030460, Raw: !AIVDM,1,1,,A,1:U8lO0P00Ld5S=jAIHWuOwd0@OJ,0*51
#   Lat: -23.99173, Lon: -46.293163, Speed: 0.0
# Type: 3, MMSI: 314481000, Raw: !AIVDM,1,1,,B,34crIJ0000Ld6B5jAl?9nUu`04kS,0*0A
#   Lat: -23.980273, Lon: -46.290663, Speed: 0.0
# Type: 1, MMSI: 710006712, Raw: !AIVDM,1,1,,A,1:U7Gf0P00tcwTujCEA>4?wb2D1p,0*75
#   Lat: -23.938873, Lon: -46.31355, Speed: 0.0
# Type: 3, MMSI: 255802350, Raw: !AIVDM,1,1,,A,33ktssQ303tce2;j:oLaTi;f0Der,0*32
#   Lat: -24.17005, Lon: -46.376845, Speed: 0.3
# Type: 1, MMSI: 710006591, Raw: !AIVDM,1,1,,B,1:U7G?hP00td0lUjCGOv4?wb26sd,0*4F
#   Lat: -23.937922, Lon: -46.309303, Speed: 0.0
# Type: 5, MMSI: 712204006, Raw: !AIVDM,2,1,3,A,5:W=Nq`000000000000tm>1QHTV222222222221@00000t00000000000000,0*26 + !AIVDM,2,2,3,A,00000000000,2*27
#   Vessel Name: N/A, Ship Type: 80
# Type: 1, MMSI: 710033530, Raw: !AIVDM,1,1,,B,1:U90NPP00Ld51IjAAReKgwf0L2a,0*16
#   Lat: -23.995077, Lon: -46.294967, Speed: 0.0
# Type: 18, MMSI: 710006171, Raw: !AIVDM,1,1,,B,B:U7EVh00;?8mP=18D3Q3wwP2h06,0*68
#   Lat: 91.0, Lon: 181.0, Speed: 0.0
# Message Types: {3: 7, 5: 2, 1: 10, 18: 1}
# Unique MMSIs: 16
# Decoding complete. Results saved to decoded_ais_data.parquet. Errors logged to ais_errors.txt

# %%
# Load and display the first few rows of the Parquet file
df = pd.read_parquet("decoded_ais_data.parquet")
df.head()
# Out:
#    msg_type       mmsi        lat        lon  speed  course vessel_name  \
# 0         1  538011058 -24.129660 -46.271113    0.0   170.9        None
# 1         1  710003185 -23.874703 -46.373788    0.0   196.9        None
# 2         1  538010074 -23.988802 -46.292782    5.6    45.7        None
# 3         1  636018551 -23.953395 -46.307160    7.5   330.0        None
# 4         1  710028580 -23.968200 -46.290470    0.0   173.1        None
#
#    ship_type       timestamp  \
# 0        NaN  09-11 00:00:01
# 1        NaN  09-11 00:00:01
# 2        NaN  09-11 00:00:01
# 3        NaN  09-11 00:00:01
# 4        NaN  09-11 00:00:01
#
#                                                  raw
# 0  !AIVDM,1,1,,B,1815UdP000Ld<0aj<F76cC5f0@Q6,0*4...
# 1  !AIVDM,1,1,,A,1:U79tHP00LcesOjEcbWdOwf26sd,0*3...
# 2  !AIVDM,1,1,,A,1815QnP00pLd5bGjAP?ijA;R00RU,0*6...
# 3  !AIVDM,1,1,,B,19NSOMh2i;Ld1LijBk>tq:Kj0<3C,0*1...
# 4  !AIVDM,1,1,,B,1:U8e90P00Ld6EejB@R6hwwj0<2u,0*0...
